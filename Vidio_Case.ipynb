# %% [markdown]
# <a href="https://colab.research.google.com/github/rfaoktvian/Chronic-Kidney-Disease/blob/main/Vidio_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %% [markdown]
# ### LOAD DATA

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Job Seek/Vidio/vidio_dataset.csv'
df = pd.read_csv(path,on_bad_lines='skip',engine='python')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### DATA UNDERSTANDING

# %%
df.head()
# Out:
#                                      hash_content_id  \
# 0  003f6dad4ab48a4e39ea262b19e3b42a4b53c2175078b3...
# 1  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 2  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 3  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 4  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
#
#                                         hash_play_id  \
# 0  515dd4d7af23ae9ef5a2455bc97ee765fe86224ebaca71...
# 1  047f7b21bcb1a57119229958b11abe364ce1a279f8ae00...
# 2  2623b2970635a15f1cf12bf9aa1e4d545135593e6a860c...
# 3  4850defe8308149c097ff7adfe6fbdab1385a4d2ea7038...
# 4  ae0cb715407a6694fb052f4d25b9c87e97ab6ccafdb388...
#
#                                        hash_visit_id  \
# 0  ed8d97adbba52562575973553003d9a13b103bc4693a6c...
# 1  88a404df574ba3c637bb99e94a2e51b16114f5da6f99cd...
# 2  24abc04f114c9cb0c2087568093a909f04b3a567041fff...
# 3  f1279ae82e3c45f7591ad8e43f69a87d7444bf1c4b70b1...
# ...

# %%
df.shape
# Out:
# (731622, 41)

# %%
df.describe()
# Out:
#        average_bitrate   total_bytes  buffer_duration  city  play_duration
# count    697042.000000  7.316220e+05     7.316220e+05   0.0  731622.000000
# mean     199642.859208  8.154527e+07     4.131891e+02   NaN     438.022129
# std      141318.399261  5.174427e+08     7.242157e+04   NaN    1662.884277
# min         144.000000  0.000000e+00    -4.639000e+00   NaN       0.000000
# 25%         633.000000  7.500000e+02     1.400000e-02   NaN       3.000000
# 50%      300000.000000  5.250000e+05     1.000000e+00   NaN      40.000000
# 75%      300000.000000  1.125000e+07     6.000000e+00   NaN     120.000000
# max      300000.000000  5.065312e+10     6.117224e+07   NaN  135075.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731622 entries, 0 to 731621
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hash_content_id    731622 non-null  object
#  1   hash_play_id       731622 non-null  object
#  2   hash_visit_id      731622 non-null  object
#  3   hash_watcher_id    731622 non-null  object
#  4   hash_film_id       40454 non-null   object
#  5   hash_event_id      731622 non-null  object
#  6   is_login           731622 non-null  bool
#  7   playback_location  731622 non-null  object
#  8   platform           731622 non-null  object
#  9   play_time          731622 non-null  object
#  10  end_time           731622 non-null  object
#  11  referrer           691287 non-null  object
#  12  average_bitrate    697042 non-null  float64
#  13  bitrate_range      731622 non-null  object
#  14  total_bytes        731622 non-null  int64
# ...

# %%
missing = pd.DataFrame({
    'Missing Count': df.isnull().sum(),
    'Missing Percentage': round((df.isnull().sum()/len(df))*100,2)
})

display(
    missing.sort_values(
        by='Missing Percentage',
        ascending=False
    )
)
# Out:
#                    Missing Count  Missing Percentage
# city                      731622              100.00
# utm_campaign              731311               99.96
# utm_medium                730865               99.90
# utm_source                730862               99.90
# genre_name                695662               95.08
# film_title                691181               94.47
# season_name               691168               94.47
# hash_film_id              691168               94.47
# app_version               491624               67.20
# stream_type               462166               63.17
# autoplay                  269602               36.85
# category_name             269456               36.83
# completed                 269456               36.83
# browser_version           249659               34.12
# flash_version             241248               32.97
# os_name                   233678               31.94
# browser_name              233039               31.85
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique().sort_values()
# Out:
# city                      0
# is_login                  2
# has_ad                    2
# playback_location         2
# is_premium                2
# autoplay                  2
# stream_type               2
# completed                 2
# app_name                  3
# content_type              3
# bitrate_range             3
# player_name               3
# platform                  7
# utm_medium                8
# utm_source               12
# category_name            15
# os_name                  16
# utm_campaign             16
# referrer_group           17
# browser_name             51
# flash_version            60
# season_name             153
# app_version             154
# os_version              269
# genre_name              528
# average_bitrate         638
# film_title              665
# hash_film_id            668
# browser_version        1024
# play_duration          7157
# total_bytes           10506
# title                 32332
# hash_content_id       33561
# ...

# %%
cols_cek = [
    'platform', 'content_type', 'playback_location',
    'referrer_group', 'bitrate_range', 'stream_type',
    'os_name', 'app_name', 'player_name'
]

for col in cols_cek:
    print(f"\n── {col} ──")
    print(df[col].value_counts(dropna=False).to_string())
# Out:
# ── platform ──
# platform
# web-mobile     420109
# app-android    179187
# web-desktop     70265
# tv-android      41352
# app-ios         12500
# tv-tizen         7041
# tv-webos         1168
#
# ── content_type ──
# content_type
# vod              459321
# livestreaming    269456
# catchup            2845
#
# ── playback_location ──
# playback_location
# embed     370030
# direct    361592
#
# ── referrer_group ──
# referrer_group
# others       244991
# kapanlagi    108243
# internal      77613
# liputan6      72291
# merdeka       71837
# dream         44887
# empty         40335
# google        23877
# bola          20856
# bolanet       17049
# otosia         4045
# fimela         3851
# emtek           785
# facebook        587
# telkomsel       295
# twitter          79
# brilio            1
#
# ── bitrate_range ──
# bitrate_range
# 200-500    463359
# 0-200      233683
# unknown     34580
#
# ── stream_type ──
# stream_type
# NaN            462166
# TvStream       264990
# ...

# %% [markdown]
# ### DATA PREPROCESSING

# %%
df_clean = df.copy()

# %%
df_clean.head()
# Out:
#                                      hash_content_id  \
# 0  003f6dad4ab48a4e39ea262b19e3b42a4b53c2175078b3...
# 1  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 2  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 3  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
# 4  0079c67ae8c7f6cbd44768f1988196c137326f3058d995...
#
#                                         hash_play_id  \
# 0  515dd4d7af23ae9ef5a2455bc97ee765fe86224ebaca71...
# 1  047f7b21bcb1a57119229958b11abe364ce1a279f8ae00...
# 2  2623b2970635a15f1cf12bf9aa1e4d545135593e6a860c...
# 3  4850defe8308149c097ff7adfe6fbdab1385a4d2ea7038...
# 4  ae0cb715407a6694fb052f4d25b9c87e97ab6ccafdb388...
#
#                                        hash_visit_id  \
# 0  ed8d97adbba52562575973553003d9a13b103bc4693a6c...
# 1  88a404df574ba3c637bb99e94a2e51b16114f5da6f99cd...
# 2  24abc04f114c9cb0c2087568093a909f04b3a567041fff...
# 3  f1279ae82e3c45f7591ad8e43f69a87d7444bf1c4b70b1...
# ...

# %% [markdown]
# #### Drop Unecessary Column

# %%
drop_cols = ['city', 'flash_version',
             'utm_source', 'utm_medium', 'utm_campaign']

df_clean.drop(columns=drop_cols, inplace=True)
print(f"Kolom dihapus : {drop_cols}")
print(f"Sisa kolom    : {df_clean.shape[1]}")
# Out:
# Kolom dihapus : ['city', 'flash_version', 'utm_source', 'utm_medium', 'utm_campaign']
# Sisa kolom    : 36
